# %% [markdown]
# # 05 — Modeling

# %% [markdown]
# ## Setup

# %% [markdown]
# ## 1. Markdown: framing

# %% [markdown]
# ## 2. Feature sets

# %% [markdown]
# ## 3. Split

# %% [markdown]
# ## 4. Baseline model

# %% [markdown]
# ## 5. Evaluation

# %% [markdown]
# ## 6. Tree ensemble

# %% [markdown]
# ## 7. Reapeat 5-7 on set 2
# (with diabetes_type)

# %% [markdown]
# ## 8. Threshold selection

# %% [markdown]
# ## 9. SHAP
